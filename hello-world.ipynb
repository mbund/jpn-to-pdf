# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(20, 40, 100)
plt.plot(x, np.sin(x))
plt.show()

print("hello world")
# Out:
# hello world

# %% [markdown]
# # Hello

# %%
import pandas as pd
import numpy as np

s = pd.Series([ 1, 3, 5, np.nan, 6, 8 ])
